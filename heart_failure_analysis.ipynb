# %%
import pandas as pd
import numpy as  np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('heart.csv')
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df.shape
# Out:
# (918, 12)

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
plt.figure(figsize=(10, 7))

sns.heatmap(df.corr(numeric_only=True),
            annot=True,
            cmap="Purples",
            fmt=".2f",
            linewidths=0.5)

plt.title("Correlation Heatmap")
plt.show()

# %%
df["HeartDisease"].value_counts()
# Out:
# HeartDisease
# 1    508
# 0    410
# Name: count, dtype: int64

# %%
sns.countplot(data=df,x="HeartDisease")
# Out:
# <Axes: xlabel='HeartDisease', ylabel='count'>

# %%
df["Sex"].value_counts()
# Out:
# Sex
# M    725
# F    193
# Name: count, dtype: int64

# %%
sns.countplot(data=df,x="Sex").set_title("Data Presence")
# Out:
# Text(0.5, 1.0, 'Data Presence')

# %%
df.groupby(["Sex","HeartDisease"]).size()
# Out:
# Sex  HeartDisease
# F    0               143
#      1                50
# M    0               267
#      1               458
# dtype: int64

# %%
sns.countplot(x="Sex",hue="HeartDisease",data=df)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
143+50
# Out:
# 193

# %%
f=(50*100)/193
f
# Out:
# 25.906735751295336

# %%
267+458
# Out:
# 725

# %%
m=(267*100)/725
m
# Out:
# 36.827586206896555

# %% [markdown]
# 25.90% females value are showing Heartdisease
#
# 36.82% males value are showing Heartdisease

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df["ChestPainType"].value_counts()
# Out:
# ChestPainType
# ASY    496
# NAP    203
# ATA    173
# TA      46
# Name: count, dtype: int64

# %%
sns.countplot(x="ChestPainType",data=df).set_title("Chest Pain Type")
#plt.grid()
# Out:
# Text(0.5, 1.0, 'Chest Pain Type')

# %%
df.head(2)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1

# %%
sns.displot(x="Age",kde=True,data=df)

# %%
sns.displot(x="Age",hue= "HeartDisease",kde=True,data=df)

# %%
sns.displot(x="RestingBP",kde=True,data=df)

# %%
sns.displot(x="RestingBP",hue= "HeartDisease",kde=True,data=df)

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
sns.displot(x="Cholesterol",kde=True,data=df)

# %%
sns.displot(x="Cholesterol",hue= "HeartDisease",kde=True,data=df)

# %%
df["Cholesterol"].unique()
# Out:
# array([289, 180, 283, 214, 195, 339, 237, 208, 207, 284, 211, 164, 204,
#        234, 273, 196, 201, 248, 267, 223, 184, 288, 215, 209, 260, 468,
#        188, 518, 167, 224, 172, 186, 254, 306, 250, 177, 227, 230, 294,
#        264, 259, 175, 318, 216, 340, 233, 205, 245, 194, 270, 213, 365,
#        342, 253, 277, 202, 297, 225, 246, 412, 265, 182, 218, 268, 163,
#        529, 100, 206, 238, 139, 263, 291, 229, 307, 210, 329, 147,  85,
#        269, 275, 179, 392, 466, 129, 241, 255, 276, 282, 338, 160, 156,
#        272, 240, 393, 161, 228, 292, 388, 166, 247, 331, 341, 243, 279,
#        198, 249, 168, 603, 159, 190, 185, 290, 212, 231, 222, 235, 320,
#        187, 266, 287, 404, 312, 251, 328, 285, 280, 192, 193, 308, 219,
#        257, 132, 226, 217, 303, 298, 256, 117, 295, 173, 315, 281, 309,
#        200, 336, 355, 326, 171, 491, 271, 274, 394, 221, 126, 305, 220,
#        242, 347, 344, 358, 169, 181,   0, 236, 203, 153, 316, 311, 252,
# ...

# %%
df["Cholesterol"].value_counts()
# Out:
# Cholesterol
# 0      172
# 254     11
# 220     10
# 223     10
# 204      9
#       ...
# 353      1
# 278      1
# 157      1
# 176      1
# 131      1
# Name: count, Length: 222, dtype: int64

# %%
sns.countplot(x="RestingECG",data=df)
# Out:
# <Axes: xlabel='RestingECG', ylabel='count'>

# %%
sns.countplot(x="RestingECG",hue="HeartDisease",data=df)
# Out:
# <Axes: xlabel='RestingECG', ylabel='count'>

# %%
df.head(2)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1

# %%
df["FastingBS"].unique()
# Out:
# array([0, 1])

# %%
df["FastingBS"].value_counts()
# Out:
# FastingBS
# 0    704
# 1    214
# Name: count, dtype: int64

# %%
sns.countplot(x="FastingBS",data=df)
# Out:
# <Axes: xlabel='FastingBS', ylabel='count'>

# %%
sns.countplot(x="FastingBS",hue="HeartDisease",data=df)
# Out:
# <Axes: xlabel='FastingBS', ylabel='count'>

# %%
df.head(2)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1

# %%
df["ST_Slope"].unique()
# Out:
# array(['Up', 'Flat', 'Down'], dtype=object)

# %%
df["ST_Slope"].value_counts()
# Out:
# ST_Slope
# Flat    460
# Up      395
# Down     63
# Name: count, dtype: int64

# %%
sns.countplot(x="ST_Slope",data=df)
# Out:
# <Axes: xlabel='ST_Slope', ylabel='count'>

# %%
sns.countplot(x="ST_Slope",hue="HeartDisease",data=df)
# Out:
# <Axes: xlabel='ST_Slope', ylabel='count'>
